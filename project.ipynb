# %%
print("Hello World")
# Out:
# Hello World

# %%
**Step 1 Data Exploration & Leading**

# %%
#importing dependencies

import pandas as pd

#mysql toolkit
import pymysql #this will work as adapter 
from sqlalchemy import create_engine 

#psql
import psycopg2

# %%
print(pd.__version__)
# Out:
# 2.3.3

# %%
df.shape
# Out:
# (52120, 7)

# %%
df.head()
# Out:
#        brand_name           pants_description   price     MRP  \
# 0           WROGN  Men Loose Fit Cotton Jeans  1374.0  2499.0
# 1  Flying Machine          Men Slim Fit Jeans  1829.0  2999.0
# 2        Roadster       Men Pure Cotton Jeans   974.0  2499.0
# 3      Bene Kleed     Relaxed Fit Denim Jeans   873.0  2299.0
# 4           Levis      Men 511 Slim Fit Jeans  1478.0  2899.0
#
#    discount_percent  ratings  number_of_ratings
# 0              0.45      4.2               57.0
# 1              0.39      4.6                5.0
# 2              0.61      3.6             1100.0
# 3              0.62      4.0             4800.0
# 4              0.49      4.3              264.0

# %%
df.describe()
# Out:
#               price           MRP  discount_percent       ratings  \
# count  52120.000000  52120.000000      52120.000000  52120.000000
# mean    1594.515445   3180.398438          1.648256      3.997794
# std     1495.972325   2201.883218          4.687529      0.420404
# min      337.000000    499.000000          0.020000      1.000000
# 25%      989.000000   2499.000000          0.400000      3.800000
# 50%     1439.000000   2999.000000          0.500000      4.000000
# 75%     1829.000000   3499.000000          0.630000      4.200000
# max    54000.000000  72000.000000         64.000000      5.000000
#
#        number_of_ratings
# count       52120.000000
# mean           91.568937
# std           433.918513
# min             5.000000
# 25%            16.000000
# 50%            35.000000
# 75%            74.000000
# max         30700.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52120 entries, 0 to 52119
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand_name         52120 non-null  object
#  1   pants_description  52120 non-null  object
#  2   price              52120 non-null  float64
#  3   MRP                52120 non-null  float64
#  4   discount_percent   52120 non-null  float64
#  5   ratings            52120 non-null  float64
#  6   number_of_ratings  52120 non-null  float64
# dtypes: float64(5), object(2)
# memory usage: 2.8+ MB

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.3.3

# %%
df = pd.read_csv("myntra-sales-dataset/myntra_dataset_ByScraping.csv" , encoding='latin1')

# %%
df.shape
# Out:
# (52120, 7)

# %%
df.head()
# Out:
#        brand_name           pants_description  price     MRP  \
# 0           WROGN  Men Loose Fit Cotton Jeans   1374  2499.0
# 1  Flying Machine          Men Slim Fit Jeans   1829  2999.0
# 2        Roadster       Men Pure Cotton Jeans    974  2499.0
# 3      Bene Kleed     Relaxed Fit Denim Jeans    873  2299.0
# 4           Levis      Men 511 Slim Fit Jeans   1478  2899.0
#
#    discount_percent  ratings  number_of_ratings
# 0              0.45      4.2                 57
# 1              0.39      4.6                  5
# 2              0.61      3.6               1100
# 3              0.62      4.0               4800
# 4              0.49      4.3                264

# %%
df.describe()
# Out:
#               price           MRP  discount_percent       ratings  \
# count  52120.000000  52120.000000      52120.000000  52120.000000
# mean    1594.515445   3180.398438          1.648256      3.997794
# std     1495.972325   2201.883218          4.687529      0.420404
# min      337.000000    499.000000          0.020000      1.000000
# 25%      989.000000   2499.000000          0.400000      3.800000
# 50%     1439.000000   2999.000000          0.500000      4.000000
# 75%     1829.000000   3499.000000          0.630000      4.200000
# max    54000.000000  72000.000000         64.000000      5.000000
#
#        number_of_ratings
# count       52120.000000
# mean           91.568937
# std           433.918513
# min             5.000000
# 25%            16.000000
# 50%            35.000000
# 75%            74.000000
# max         30700.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52120 entries, 0 to 52119
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand_name         52120 non-null  object
#  1   pants_description  52120 non-null  object
#  2   price              52120 non-null  int64
#  3   MRP                52120 non-null  float64
#  4   discount_percent   52120 non-null  float64
#  5   ratings            52120 non-null  float64
#  6   number_of_ratings  52120 non-null  int64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 2.8+ MB

# %%
df.duplicated().sum()
# Out:
# np.int64(17047)

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# brand_name           0
# pants_description    0
# price                0
# MRP                  0
# discount_percent     0
# ratings              0
# number_of_ratings    0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# brand_name           0
# pants_description    0
# price                0
# MRP                  0
# discount_percent     0
# ratings              0
# number_of_ratings    0
# dtype: int64

# %%
df.shape
# Out:
# (35073, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35073 entries, 0 to 52018
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand_name         35073 non-null  object
#  1   pants_description  35073 non-null  object
#  2   price              35073 non-null  int64
#  3   MRP                35073 non-null  float64
#  4   discount_percent   35073 non-null  float64
#  5   ratings            35073 non-null  float64
#  6   number_of_ratings  35073 non-null  int64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 2.1+ MB

# %%
df.columns
# Out:
# Index(['brand_name', 'pants_description', 'price', 'MRP', 'discount_percent',
#        'ratings', 'number_of_ratings'],
#       dtype='object')

# %%
df['discount amount'] = df['MRP'] - df['price']

# %%
df.head()
# Out:
#        brand_name           pants_description  price     MRP  \
# 0           WROGN  Men Loose Fit Cotton Jeans   1374  2499.0
# 1  Flying Machine          Men Slim Fit Jeans   1829  2999.0
# 2        Roadster       Men Pure Cotton Jeans    974  2499.0
# 3      Bene Kleed     Relaxed Fit Denim Jeans    873  2299.0
# 4           Levis      Men 511 Slim Fit Jeans   1478  2899.0
#
#    discount_percent  ratings  number_of_ratings  discount amount
# 0              0.45      4.2                 57           1125.0
# 1              0.39      4.6                  5           1170.0
# 2              0.61      3.6               1100           1525.0
# 3              0.62      4.0               4800           1426.0
# 4              0.49      4.3                264           1421.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35073 entries, 0 to 52018
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand_name         35073 non-null  object
#  1   pants_description  35073 non-null  object
#  2   price              35073 non-null  int64
#  3   MRP                35073 non-null  float64
#  4   discount_percent   35073 non-null  float64
#  5   ratings            35073 non-null  float64
#  6   number_of_ratings  35073 non-null  int64
#  7   discount amount    35073 non-null  float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 2.4+ MB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# brand_name           0
# pants_description    0
# price                0
# MRP                  0
# discount_percent     0
# ratings              0
# number_of_ratings    0
# discount amount      0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35073 entries, 0 to 52018
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand_name         35073 non-null  object
#  1   pants_description  35073 non-null  object
#  2   price              35073 non-null  int64
#  3   MRP                35073 non-null  float64
#  4   discount_percent   35073 non-null  float64
#  5   ratings            35073 non-null  float64
#  6   number_of_ratings  35073 non-null  int64
#  7   discount amount    35073 non-null  float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 2.4+ MB

# %%
df.columns
# Out:
# Index(['brand_name', 'pants_description', 'price', 'MRP', 'discount_percent',
#        'ratings', 'number_of_ratings', 'discount amount'],
#       dtype='object')

# %%
import pandas as pd

# %%
df.columns
# Out:
# Index(['brand_name', 'pants_description', 'price', 'MRP', 'discount_percent',
#        'ratings', 'number_of_ratings', 'discount amount'],
#       dtype='object')

# %%
#mysql
host='localhost'
user='root'
password='your_password'
port=3306

# %%
#psql
host='localhost'
user='postgres'
password='your_password'
port=5432
database='myntra_db'

# %%
df.shape
# Out:
# (35073, 8)

# %%
df.to_csv('myntra_cleaned_data.csv', index=False)

# %%
help(create_engine)
# Out:
# Help on function create_engine in module sqlalchemy.engine.create:
#
# create_engine(url: 'Union[str, _url.URL]', **kwargs: 'Any') -> 'Engine'
#     Create a new :class:`_engine.Engine` instance.
#
#     The standard calling form is to send the :ref:`URL <database_urls>` as the
#     first positional argument, usually a string
#     that indicates database dialect and connection arguments::
#
#         engine = create_engine("postgresql+psycopg2://scott:tiger@localhost/test")
#
#     .. note::
#
#         Please review :ref:`database_urls` for general guidelines in composing
#         URL strings.  In particular, special characters, such as those often
#         part of passwords, must be URL encoded to be properly parsed.
#
#     Additional keyword arguments may then follow it which
#     establish various options on the resulting :class:`_engine.Engine`
#     and its underlying :class:`.Dialect` and :class:`_pool.Pool`
#     constructs::
#
#         engine = create_engine(
# ...

# %%
#mysql connection
#mysql+pymysql://root@localhost:3306/myntra_db
engine_mysql = create_engine("mysql+pymysql://root@localhost:3306/myntra_db")

try:
    engine_mysql
    print("connection successed to mysql")
except:
    print("unable to connect")
# Out:
# connection successed to mysql

# %%
df.columns
# Out:
# Index(['brand_name', 'pants_description', 'price', 'MRP', 'discount_percent',
#        'ratings', 'number_of_ratings', 'discount amount'],
#       dtype='object')

# %%
df.columns = (
    df.columns
    .str.strip()
    .str.lower()
    .str.replace(' ', '_')
)

# %%
df = df.fillna(0)

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
#mysql connection
#mysql+pymysql://root@localhost:3306/myntra_db
engine_mysql = create_engine("mysql+pymysql://root@localhost:3306/myntra_db")

try:
    engine_mysql
    print("connection successed to mysql")
except:
    print("unable to connect")
# Out:
# connection successed to mysql

# %%
df.to_sql
# Out:
# <bound method NDFrame.to_sql of                       brand_name            pants_description  price     MRP  \
# 0                          WROGN   Men Loose Fit Cotton Jeans   1374  2499.0
# 1                 Flying Machine           Men Slim Fit Jeans   1829  2999.0
# 2                       Roadster        Men Pure Cotton Jeans    974  2499.0
# 3                     Bene Kleed      Relaxed Fit Denim Jeans    873  2299.0
# 4                          Levis       Men 511 Slim Fit Jeans   1478  2899.0
# ...                          ...                          ...    ...     ...
# 35068  United Colors of Benetton  Men Slim Fit Mid-Rise Jeans    949  3049.0
# 35069                   HERE&NOW           Men Slim Fit Jeans    759  1899.0
# 35070                 Pepe Jeans    Men Vapour Slim Fit Jeans    759  1899.0
# 35071                 Pepe Jeans           Men Slim Fit Jeans    759  1899.0
# 35072                      Celio       Men Straight Fit Jeans    759  1899.0
#
# ...

# %%
df.head()
# Out:
#        brand_name           pants_description  price     MRP  \
# 0           WROGN  Men Loose Fit Cotton Jeans   1374  2499.0
# 1  Flying Machine          Men Slim Fit Jeans   1829  2999.0
# 2        Roadster       Men Pure Cotton Jeans    974  2499.0
# 3      Bene Kleed     Relaxed Fit Denim Jeans    873  2299.0
# 4           Levis      Men 511 Slim Fit Jeans   1478  2899.0
#
#    discount_percent  ratings  number_of_ratings  discount amount
# 0              0.45      4.2                 57           1125.0
# 1              0.39      4.6                  5           1170.0
# 2              0.61      3.6               1100           1525.0
# 3              0.62      4.0               4800           1426.0
# 4              0.49      4.3                264           1421.0

# %%
import pandas as pd

df = pd.read_csv("myntra_cleaned_data.csv")

# %%
from sqlalchemy import create_engine

engine_psql = create_engine(
    "postgresql+psycopg2://postgres:password123@localhost:5432/walmart_inlighn"
)

print("Connection success")
# Out:
# Connection success

# %%
from sqlalchemy import create_engine

# %%
import pandas as pd

# %%
df = pd.read_csv("myntra_cleaned_data.csv")

# %%
#mysql connection
#mysql+pymysql://root@localhost:3306/myntra_db
engine_mysql = create_engine("mysql+pymysql://root@localhost:3306/myntra_db")

try:
    engine_mysql
    print("connection successed to mysql")
except:
    print("unable to connect")
# Out:
# connection successed to mysql

# %%
df.to_sql
# Out:
# <bound method NDFrame.to_sql of                       brand_name            pants_description  price     MRP  \
# 0                          WROGN   Men Loose Fit Cotton Jeans   1374  2499.0
# 1                 Flying Machine           Men Slim Fit Jeans   1829  2999.0
# 2                       Roadster        Men Pure Cotton Jeans    974  2499.0
# 3                     Bene Kleed      Relaxed Fit Denim Jeans    873  2299.0
# 4                          Levis       Men 511 Slim Fit Jeans   1478  2899.0
# ...                          ...                          ...    ...     ...
# 35068  United Colors of Benetton  Men Slim Fit Mid-Rise Jeans    949  3049.0
# 35069                   HERE&NOW           Men Slim Fit Jeans    759  1899.0
# 35070                 Pepe Jeans    Men Vapour Slim Fit Jeans    759  1899.0
# 35071                 Pepe Jeans           Men Slim Fit Jeans    759  1899.0
# 35072                      Celio       Men Straight Fit Jeans    759  1899.0
#
# ...

# %%
con=engine_mysql

# %%
if_exists='replace'

# %%
index=False

# %%
name='myntra_sales_data'

# %%
df.shape
# Out:
# (35073, 8)

# %%
from sqlalchemy import create_engine
engine = create_engine

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
df = pd.read_csv("myntra_cleaned_data.csv")
df.head()
# Out:
#        brand_name           pants_description  price     MRP  \
# 0           WROGN  Men Loose Fit Cotton Jeans   1374  2499.0
# 1  Flying Machine          Men Slim Fit Jeans   1829  2999.0
# 2        Roadster       Men Pure Cotton Jeans    974  2499.0
# 3      Bene Kleed     Relaxed Fit Denim Jeans    873  2299.0
# 4           Levis      Men 511 Slim Fit Jeans   1478  2899.0
#
#    discount_percent  ratings  number_of_ratings  discount amount
# 0              0.45      4.2                 57           1125.0
# 1              0.39      4.6                  5           1170.0
# 2              0.61      3.6               1100           1525.0
# 3              0.62      4.0               4800           1426.0
# 4              0.49      4.3                264           1421.0

# %%
import os
os.listdir()
# Out:
# ['myntra-sales-dataset',
#  'myntra-sales-dataset.zip',
#  'myntra_cleaned_data.csv',
#  'my_env1',
#  'project.ipynb',
#  'requirements.txt']

# %%
df.shape
df.head()
# Out:
#        brand_name           pants_description  price     MRP  \
# 0           WROGN  Men Loose Fit Cotton Jeans   1374  2499.0
# 1  Flying Machine          Men Slim Fit Jeans   1829  2999.0
# 2        Roadster       Men Pure Cotton Jeans    974  2499.0
# 3      Bene Kleed     Relaxed Fit Denim Jeans    873  2299.0
# 4           Levis      Men 511 Slim Fit Jeans   1478  2899.0
#
#    discount_percent  ratings  number_of_ratings  discount amount
# 0              0.45      4.2                 57           1125.0
# 1              0.39      4.6                  5           1170.0
# 2              0.61      3.6               1100           1525.0
# 3              0.62      4.0               4800           1426.0
# 4              0.49      4.3                264           1421.0

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "mysql+mysqlconnector://root:password@localhost:3306/myntra_db"
)

# %%
df.to_sql(
    name="myntra_sales",
    con=engine,
    if_exists="replace",   # first time
    index=False
)
# Out:
# 35073

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine(
    "postgresql+psycopg2://postgres:x0000@localhost:5432/myntra_db"
)

# %%
#psql connection
#mysql+pymysql://root@localhost:3306/myntra_db
engine_psql = create_engine("postgresql://postgres:x0000@localhost:5432/myntra_db")

try:
    engine_psql
    print("connection successed to psql")
except:
    print("unable to connect")
# Out:
# connection successed to psql

# %%
import pandas as pd
df = pd.read_csv("myntra_cleaned_data.csv")

# %%
from sqlalchemy import create_engine

engine_psql = create_engine("postgresql://postgres:x0000@localhost:5432/myntra_db")

# %%
from sqlalchemy import create_engine

engine_psql = create_engine("postgresql://postgres:password123@localhost:5432/myntra_db")

# %%
import pandas as pd

# %%
df.to_sql(
    name="myntra_sales",
    con=engine_psql,
    if_exists="replace",
    index=False
)
# Out:
# 73
